# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sb

# %%
df=pd.read_csv('Weather Dataset.csv')
df.shape
# Out:
# (3780, 12)

# %%
pd.isnull(df).sum().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df=df.drop(index=3247)
df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 2515  2006-02-20 19:00:00.000 +0100  Partly Cloudy        rain
# 2516  2006-02-20 20:00:00.000 +0100  Mostly Cloudy        rain
# 2517  2006-02-20 21:00:00.000 +0100  Mostly Cloudy        rain
# 2518  2006-02-20 22:00:00.000 +0100  Mostly Cloudy        rain
# 2519  2006-02-20 23:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
df=df.drop(index=236)

# %%
plt.plot(df['Formatted Date'],df['Temperature (C)'])
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Temp vs Time')
plt.savefig('anything.png')
plt.show()

# %%
plt.hist(df['Temperature (C)'],bins=30,edgecolor='black')
plt.xlabel('Temperature (C)')
plt.ylabel('Number of time')
# Out:
# Text(0, 0.5, 'Number of time')

# %%
df['Humidity']
# Out:
# 0       0.89
# 1       0.86
# 2       0.89
# 3       0.83
# 4       0.83
#         ...
# 2515    0.82
# 2516    0.78
# 2517    0.74
# 2518    0.77
# 2519    0.83
# Name: Humidity, Length: 2519, dtype: float64

# %%
plt.scatter(df['Temperature (C)'],df['Humidity'],s=100,edgecolor='black',linewidth=0.55)
plt.xlabel('Temperature (C)')
plt.ylabel('Humidity')
plt.tight_layout()
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number']).corr()
corr_matrix = numeric_df.corr()
sb.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.show()
